# %% [markdown]
# <a href="https://colab.research.google.com/github/BeushevArtem/project/blob/main/Ledapok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import math as m
fig = plt.figure()
tur = []
rty=300;
for i in range (0,10001):
    rty = rty + 0.02
    tur.append(rty)
T = [(m.atan(-0.0012*t*t*t + 0.4*t*t+0.616*t+6120) + 0.65*m.sin(0.24*t + 1.23) - 0.27*m.cos(0.21*t - 0.17) - (m.sin(0.34*t + 0.16))/(1+0.03*(t-370.5)**2)) for t in tur]
plt.plot(tur,T)
plt.show()
for i in range (0,1000):    
    T = [(m.atan(-0.0012*t*t*t + 0.4*t*t+0.616*t+6120) + 0.65*m.sin(0.24*t + 1.23) - 0.27*m.cos(0.21*t - 0.17) - (m.sin(0.34*t + 0.16))/(1+0.03*(t-370.5)**2)) for t in tur]
